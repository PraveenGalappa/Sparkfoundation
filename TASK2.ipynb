# %% [markdown]
# # Data Science & Business Analytics Task 1
# *Author : PRAVEEN GALAPPA*

# %% [markdown]
# # Data Preparation
# Data preparation is the initial step after we get our hands on the Task2. Then we need to import some of the libraries as python library. These libraries are a set of functions and methods that enables us to perform multiple actions without writing code

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %% [markdown]
# # Reading data

# %%
 Task2= pd.read_csv('Iris.csv').iloc[:, 1:]

# %% [markdown]
# # Data Exploration
# Here the users explore a broad data collection to discover initial trends, features and points of interest in an unstructured way.
# Data exploration can be used as a combination of manual methods and automated tools such as visualizations of results, maps, and initial reports.

# %%
print(Task2.head())
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Task2.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # Check for Null Value

# %%
print(Task2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
# Visualization

# %%
import seaborn as sns
sns.distplot(Task2['SepalLengthCm'])
plt.xlabel('sepal length')
plt.ylabel('Probability')
plt.title('Distribution Plot')
plt.show()

# %%
sns.distplot(Task2['SepalWidthCm'])
plt.xlabel('sepal Width')
plt.ylabel('Probability')
plt.title('Distribution Plot')
plt.show()

# %%
sns.distplot(Task2['PetalLengthCm'])
plt.xlabel('Petal length')
plt.ylabel('Probability')
plt.title('Distribution Plot')
plt.show()

# %%
sns.distplot(Task2['PetalWidthCm'],)
plt.xlabel('Petal Width')
plt.ylabel('Probability')
plt.title('Distribution Plot')
plt.show()

# %%
Task2.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
sns.pairplot(Task2,hue="Species",palette="husl")
plt.show()

# %%
axis = sns.heatmap(Task2.corr(),annot=True,linecolor="white",cmap=['orange','black'])
bottom,top = axis.get_ylim()
axis.set_ylim(bottom,top)
plt.show()

# %%
x = Task2.iloc[:,[0,1,2,3]].values
from sklearn.cluster import KMeans
with_in_cluster_sum_square = []
for i in range(1,11):
    Kmeans = KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=0)
    Kmeans.fit(x)
    with_in_cluster_sum_square.append(Kmeans.inertia_)

# %%
plt.plot(range(1,11),with_in_cluster_sum_square )
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('with_in_cluster_sum_square')
plt.show()

# %%
Kmeans = KMeans(n_clusters=3,init='k-means++',max_iter=300,n_init=10,random_state=0)
y_Kmeans = Kmeans.fit_predict(x)

# %% [markdown]
# # Predictions

# %%
plt.scatter(x[y_Kmeans==0,0],x[y_Kmeans==0,1],s=100,c='red',label='Iris-setosa')
plt.scatter(x[y_Kmeans==1,0],x[y_Kmeans==1,1],s=100,c='blue',label='Iris-versicolour')
plt.scatter(x[y_Kmeans==2,0],x[y_Kmeans==2,1],s=100,c='green',label='Iris-verginica')
#plotting centroid of cluster
plt.scatter(Kmeans.cluster_centers_[:,0],Kmeans.cluster_centers_[:,1],s=100,c='yellow',label='Centroids')
plt.legend()
